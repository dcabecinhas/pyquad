# %%
# %matplotlib widget

# Needs this line or else pandas plots do not show in jupyterlab
# %matplotlib inline

import rosbag_pandas
import pandas as pd

from matplotlib.pyplot import *

sys.path.append('../src')
from frame_conversions import *
from single_quadrotor import *

from scipy.integrate import solve_ivp, cumtrapz
from scipy.linalg import null_space, expm, inv, norm, eig
# Out:
# Failed to load Python extension for LZ4 support. LZ4 compression will not be available.

# %%
# Fixed omega computation
try:
#     df = rosbag_pandas.bag_to_dataframe('/home/dcabecinhas/gazebo_logs/rigid_body_load_1_vehicle_2019-08-27-12-36-13.bag')
    df = rosbag_pandas.bag_to_dataframe('/home/dcabecinhas/gazebo_logs/rigid_body_load_4_vehicles_2019-09-08-21-48-06.bag')
except TypeError:
    print("Check if file exists!")

# %%
# Filter only interesting trajectory segment
df = df.between_time('00:00:20', '00:00:50')

# Resample at 50Hz so we can do copmutations between dataframes
df = df.resample('20ms').last()
df = df.fillna(method='backfill')

# %% [markdown]
# List of columns that are not covariances

# %%
# List topics
topics = [col for col in df.columns if 'cov' not in col]
topics.sort()
[print(elem) for elem in topics];
# Out:
# cable_0_force__wrench_force_x
# cable_0_force__wrench_force_y
# cable_0_force__wrench_force_z
# cable_0_force__wrench_torque_x
# cable_0_force__wrench_torque_y
# cable_0_force__wrench_torque_z
# cable_0_odom__child_frame_id
# cable_0_odom__pose_pose_orientation_w
# cable_0_odom__pose_pose_orientation_x
# cable_0_odom__pose_pose_orientation_y
# cable_0_odom__pose_pose_orientation_z
# cable_0_odom__pose_pose_position_x
# cable_0_odom__pose_pose_position_y
# cable_0_odom__pose_pose_position_z
# cable_0_odom__twist_twist_angular_x
# cable_0_odom__twist_twist_angular_y
# cable_0_odom__twist_twist_angular_z
# cable_0_odom__twist_twist_linear_x
# cable_0_odom__twist_twist_linear_y
# cable_0_odom__twist_twist_linear_z
# cable_1_force__wrench_force_x
# cable_1_force__wrench_force_y
# cable_1_force__wrench_force_z
# cable_1_force__wrench_torque_x
# cable_1_force__wrench_torque_y
# cable_1_force__wrench_torque_z
# cable_1_odom__child_frame_id
# cable_1_odom__pose_pose_orientation_w
# cable_1_odom__pose_pose_orientation_x
# cable_1_odom__pose_pose_orientation_y
# cable_1_odom__pose_pose_orientation_z
# cable_1_odom__pose_pose_position_x
# cable_1_odom__pose_pose_position_y
# cable_1_odom__pose_pose_position_z
# cable_1_odom__twist_twist_angular_x
# cable_1_odom__twist_twist_angular_y
# cable_1_odom__twist_twist_angular_z
# cable_1_odom__twist_twist_linear_x
# cable_1_odom__twist_twist_linear_y
# cable_1_odom__twist_twist_linear_z
# cable_2_force__wrench_force_x
# cable_2_force__wrench_force_y
# cable_2_force__wrench_force_z
# cable_2_force__wrench_torque_x
# cable_2_force__wrench_torque_y
# cable_2_force__wrench_torque_z
# cable_2_odom__child_frame_id
# cable_2_odom__pose_pose_orientation_w
# cable_2_odom__pose_pose_orientation_x
# cable_2_odom__pose_pose_orientation_y
# cable_2_odom__pose_pose_orientation_z
# cable_2_odom__pose_pose_position_x
# cable_2_odom__pose_pose_position_y
# cable_2_odom__pose_pose_position_z
# cable_2_odom__twist_twist_angular_x
# cable_2_odom__twist_twist_angular_y
# cable_2_odom__twist_twist_angular_z
# cable_2_odom__twist_twist_linear_x
# cable_2_odom__twist_twist_linear_y
# cable_2_odom__twist_twist_linear_z
# cable_3_force__wrench_force_x
# cable_3_force__wrench_force_y
# cable_3_force__wrench_force_z
# cable_3_force__wrench_torque_x
# cable_3_force__wrench_torque_y
# cable_3_force__wrench_torque_z
# cable_3_odom__child_frame_id
# cable_3_odom__pose_pose_orientation_w
# cable_3_odom__pose_pose_orientation_x
# cable_3_odom__pose_pose_orientation_y
# cable_3_odom__pose_pose_orientation_z
# cable_3_odom__pose_pose_position_x
# cable_3_odom__pose_pose_position_y
# cable_3_odom__pose_pose_position_z
# cable_3_odom__twist_twist_angular_x
# cable_3_odom__twist_twist_angular_y
# cable_3_odom__twist_twist_angular_z
# cable_3_odom__twist_twist_linear_x
# cable_3_odom__twist_twist_linear_y
# cable_3_odom__twist_twist_linear_z
# clock__clock_nsecs
# clock__clock_secs
# iris_0_force__wrench_force_x
# iris_0_force__wrench_force_y
# iris_0_force__wrench_force_z
# iris_0_force__wrench_torque_x
# iris_0_force__wrench_torque_y
# iris_0_force__wrench_torque_z
# iris_0_odom__child_frame_id
# iris_0_odom__pose_pose_orientation_w
# iris_0_odom__pose_pose_orientation_x
# iris_0_odom__pose_pose_orientation_y
# iris_0_odom__pose_pose_orientation_z
# iris_0_odom__pose_pose_position_x
# iris_0_odom__pose_pose_position_y
# iris_0_odom__pose_pose_position_z
# iris_0_odom__twist_twist_angular_x
# iris_0_odom__twist_twist_angular_y
# iris_0_odom__twist_twist_angular_z
# iris_0_odom__twist_twist_linear_x
# iris_0_odom__twist_twist_linear_y
# iris_0_odom__twist_twist_linear_z
# iris_1_force__wrench_force_x
# iris_1_force__wrench_force_y
# iris_1_force__wrench_force_z
# iris_1_force__wrench_torque_x
# iris_1_force__wrench_torque_y
# iris_1_force__wrench_torque_z
# iris_1_odom__child_frame_id
# iris_1_odom__pose_pose_orientation_w
# iris_1_odom__pose_pose_orientation_x
# iris_1_odom__pose_pose_orientation_y
# iris_1_odom__pose_pose_orientation_z
# iris_1_odom__pose_pose_position_x
# iris_1_odom__pose_pose_position_y
# iris_1_odom__pose_pose_position_z
# iris_1_odom__twist_twist_angular_x
# iris_1_odom__twist_twist_angular_y
# iris_1_odom__twist_twist_angular_z
# iris_1_odom__twist_twist_linear_x
# iris_1_odom__twist_twist_linear_y
# iris_1_odom__twist_twist_linear_z
# iris_2_force__wrench_force_x
# iris_2_force__wrench_force_y
# iris_2_force__wrench_force_z
# iris_2_force__wrench_torque_x
# iris_2_force__wrench_torque_y
# iris_2_force__wrench_torque_z
# iris_2_odom__child_frame_id
# iris_2_odom__pose_pose_orientation_w
# iris_2_odom__pose_pose_orientation_x
# iris_2_odom__pose_pose_orientation_y
# iris_2_odom__pose_pose_orientation_z
# iris_2_odom__pose_pose_position_x
# iris_2_odom__pose_pose_position_y
# iris_2_odom__pose_pose_position_z
# iris_2_odom__twist_twist_angular_x
# iris_2_odom__twist_twist_angular_y
# iris_2_odom__twist_twist_angular_z
# iris_2_odom__twist_twist_linear_x
# iris_2_odom__twist_twist_linear_y
# iris_2_odom__twist_twist_linear_z
# iris_3_force__wrench_force_x
# iris_3_force__wrench_force_y
# iris_3_force__wrench_force_z
# iris_3_force__wrench_torque_x
# iris_3_force__wrench_torque_y
# iris_3_force__wrench_torque_z
# iris_3_odom__child_frame_id
# iris_3_odom__pose_pose_orientation_w
# iris_3_odom__pose_pose_orientation_x
# iris_3_odom__pose_pose_orientation_y
# iris_3_odom__pose_pose_orientation_z
# iris_3_odom__pose_pose_position_x
# iris_3_odom__pose_pose_position_y
# iris_3_odom__pose_pose_position_z
# iris_3_odom__twist_twist_angular_x
# iris_3_odom__twist_twist_angular_y
# iris_3_odom__twist_twist_angular_z
# iris_3_odom__twist_twist_linear_x
# iris_3_odom__twist_twist_linear_y
# iris_3_odom__twist_twist_linear_z
# load_force__wrench_force_x
# load_force__wrench_force_y
# load_force__wrench_force_z
# load_force__wrench_torque_x
# load_force__wrench_torque_y
# load_force__wrench_torque_z
# load_odom__child_frame_id
# load_odom__pose_pose_orientation_w
# load_odom__pose_pose_orientation_x
# load_odom__pose_pose_orientation_y
# load_odom__pose_pose_orientation_z
# load_odom__pose_pose_position_x
# load_odom__pose_pose_position_y
# load_odom__pose_pose_position_z
# load_odom__twist_twist_angular_x
# load_odom__twist_twist_angular_y
# load_odom__twist_twist_angular_z
# load_odom__twist_twist_linear_x
# load_odom__twist_twist_linear_y
# load_odom__twist_twist_linear_z
# uav_0_mavros_extended_state__landed_state
# uav_0_mavros_extended_state__vtol_state
# uav_0_mavros_imu_data__angular_velocity_x
# uav_0_mavros_imu_data__angular_velocity_y
# uav_0_mavros_imu_data__angular_velocity_z
# uav_0_mavros_imu_data__linear_acceleration_x
# uav_0_mavros_imu_data__linear_acceleration_y
# uav_0_mavros_imu_data__linear_acceleration_z
# uav_0_mavros_imu_data__orientation_w
# uav_0_mavros_imu_data__orientation_x
# uav_0_mavros_imu_data__orientation_y
# uav_0_mavros_imu_data__orientation_z
# uav_0_mavros_local_position_odom__child_frame_id
# uav_0_mavros_local_position_odom__pose_pose_orientation_w
# uav_0_mavros_local_position_odom__pose_pose_orientation_x
# uav_0_mavros_local_position_odom__pose_pose_orientation_y
# uav_0_mavros_local_position_odom__pose_pose_orientation_z
# uav_0_mavros_local_position_odom__pose_pose_position_x
# uav_0_mavros_local_position_odom__pose_pose_position_y
# uav_0_mavros_local_position_odom__pose_pose_position_z
# uav_0_mavros_local_position_odom__twist_twist_angular_x
# uav_0_mavros_local_position_odom__twist_twist_angular_y
# uav_0_mavros_local_position_odom__twist_twist_angular_z
# uav_0_mavros_local_position_odom__twist_twist_linear_x
# uav_0_mavros_local_position_odom__twist_twist_linear_y
# uav_0_mavros_local_position_odom__twist_twist_linear_z
# uav_0_mavros_local_position_pose__pose_orientation_w
# uav_0_mavros_local_position_pose__pose_orientation_x
# uav_0_mavros_local_position_pose__pose_orientation_y
# uav_0_mavros_local_position_pose__pose_orientation_z
# uav_0_mavros_local_position_pose__pose_position_x
# uav_0_mavros_local_position_pose__pose_position_y
# uav_0_mavros_local_position_pose__pose_position_z
# uav_0_mavros_odometry_in__child_frame_id
# uav_0_mavros_odometry_in__pose_pose_orientation_w
# uav_0_mavros_odometry_in__pose_pose_orientation_x
# uav_0_mavros_odometry_in__pose_pose_orientation_y
# uav_0_mavros_odometry_in__pose_pose_orientation_z
# uav_0_mavros_odometry_in__pose_pose_position_x
# uav_0_mavros_odometry_in__pose_pose_position_y
# uav_0_mavros_odometry_in__pose_pose_position_z
# uav_0_mavros_odometry_in__twist_twist_angular_x
# uav_0_mavros_odometry_in__twist_twist_angular_y
# uav_0_mavros_odometry_in__twist_twist_angular_z
# uav_0_mavros_odometry_in__twist_twist_linear_x
# uav_0_mavros_odometry_in__twist_twist_linear_y
# uav_0_mavros_odometry_in__twist_twist_linear_z
# uav_0_mavros_setpoint_raw_target_attitude__body_rate_x
# uav_0_mavros_setpoint_raw_target_attitude__body_rate_y
# uav_0_mavros_setpoint_raw_target_attitude__body_rate_z
# uav_0_mavros_setpoint_raw_target_attitude__orientation_w
# uav_0_mavros_setpoint_raw_target_attitude__orientation_x
# uav_0_mavros_setpoint_raw_target_attitude__orientation_y
# uav_0_mavros_setpoint_raw_target_attitude__orientation_z
# uav_0_mavros_setpoint_raw_target_attitude__thrust
# uav_0_mavros_setpoint_raw_target_attitude__type_mask
# uav_0_mavros_state__armed
# uav_0_mavros_state__connected
# uav_0_mavros_state__guided
# uav_0_mavros_state__mode
# uav_0_mavros_state__system_status
# uav_0_mavros_target_actuator_control__controls0
# uav_0_mavros_target_actuator_control__controls1
# uav_0_mavros_target_actuator_control__controls2
# uav_0_mavros_target_actuator_control__controls3
# uav_0_mavros_target_actuator_control__controls4
# uav_0_mavros_target_actuator_control__controls5
# uav_0_mavros_target_actuator_control__controls6
# uav_0_mavros_target_actuator_control__controls7
# uav_0_mavros_target_actuator_control__group_mix
# uav_1_mavros_extended_state__landed_state
# uav_1_mavros_extended_state__vtol_state
# uav_1_mavros_imu_data__angular_velocity_x
# uav_1_mavros_imu_data__angular_velocity_y
# uav_1_mavros_imu_data__angular_velocity_z
# uav_1_mavros_imu_data__linear_acceleration_x
# uav_1_mavros_imu_data__linear_acceleration_y
# uav_1_mavros_imu_data__linear_acceleration_z
# uav_1_mavros_imu_data__orientation_w
# uav_1_mavros_imu_data__orientation_x
# uav_1_mavros_imu_data__orientation_y
# uav_1_mavros_imu_data__orientation_z
# uav_1_mavros_local_position_odom__child_frame_id
# uav_1_mavros_local_position_odom__pose_pose_orientation_w
# uav_1_mavros_local_position_odom__pose_pose_orientation_x
# uav_1_mavros_local_position_odom__pose_pose_orientation_y
# uav_1_mavros_local_position_odom__pose_pose_orientation_z
# uav_1_mavros_local_position_odom__pose_pose_position_x
# uav_1_mavros_local_position_odom__pose_pose_position_y
# uav_1_mavros_local_position_odom__pose_pose_position_z
# uav_1_mavros_local_position_odom__twist_twist_angular_x
# uav_1_mavros_local_position_odom__twist_twist_angular_y
# uav_1_mavros_local_position_odom__twist_twist_angular_z
# uav_1_mavros_local_position_odom__twist_twist_linear_x
# uav_1_mavros_local_position_odom__twist_twist_linear_y
# uav_1_mavros_local_position_odom__twist_twist_linear_z
# uav_1_mavros_local_position_pose__pose_orientation_w
# uav_1_mavros_local_position_pose__pose_orientation_x
# uav_1_mavros_local_position_pose__pose_orientation_y
# uav_1_mavros_local_position_pose__pose_orientation_z
# uav_1_mavros_local_position_pose__pose_position_x
# uav_1_mavros_local_position_pose__pose_position_y
# uav_1_mavros_local_position_pose__pose_position_z
# uav_1_mavros_odometry_in__child_frame_id
# uav_1_mavros_odometry_in__pose_pose_orientation_w
# uav_1_mavros_odometry_in__pose_pose_orientation_x
# uav_1_mavros_odometry_in__pose_pose_orientation_y
# uav_1_mavros_odometry_in__pose_pose_orientation_z
# uav_1_mavros_odometry_in__pose_pose_position_x
# uav_1_mavros_odometry_in__pose_pose_position_y
# uav_1_mavros_odometry_in__pose_pose_position_z
# uav_1_mavros_odometry_in__twist_twist_angular_x
# uav_1_mavros_odometry_in__twist_twist_angular_y
# uav_1_mavros_odometry_in__twist_twist_angular_z
# uav_1_mavros_odometry_in__twist_twist_linear_x
# uav_1_mavros_odometry_in__twist_twist_linear_y
# uav_1_mavros_odometry_in__twist_twist_linear_z
# uav_1_mavros_setpoint_raw_target_attitude__body_rate_x
# uav_1_mavros_setpoint_raw_target_attitude__body_rate_y
# uav_1_mavros_setpoint_raw_target_attitude__body_rate_z
# uav_1_mavros_setpoint_raw_target_attitude__orientation_w
# uav_1_mavros_setpoint_raw_target_attitude__orientation_x
# uav_1_mavros_setpoint_raw_target_attitude__orientation_y
# uav_1_mavros_setpoint_raw_target_attitude__orientation_z
# uav_1_mavros_setpoint_raw_target_attitude__thrust
# uav_1_mavros_setpoint_raw_target_attitude__type_mask
# uav_1_mavros_state__armed
# uav_1_mavros_state__connected
# uav_1_mavros_state__guided
# uav_1_mavros_state__mode
# uav_1_mavros_state__system_status
# uav_1_mavros_target_actuator_control__controls0
# uav_1_mavros_target_actuator_control__controls1
# uav_1_mavros_target_actuator_control__controls2
# uav_1_mavros_target_actuator_control__controls3
# uav_1_mavros_target_actuator_control__controls4
# uav_1_mavros_target_actuator_control__controls5
# uav_1_mavros_target_actuator_control__controls6
# uav_1_mavros_target_actuator_control__controls7
# uav_1_mavros_target_actuator_control__group_mix
# uav_2_mavros_extended_state__landed_state
# uav_2_mavros_extended_state__vtol_state
# uav_2_mavros_imu_data__angular_velocity_x
# uav_2_mavros_imu_data__angular_velocity_y
# uav_2_mavros_imu_data__angular_velocity_z
# uav_2_mavros_imu_data__linear_acceleration_x
# uav_2_mavros_imu_data__linear_acceleration_y
# uav_2_mavros_imu_data__linear_acceleration_z
# uav_2_mavros_imu_data__orientation_w
# uav_2_mavros_imu_data__orientation_x
# uav_2_mavros_imu_data__orientation_y
# uav_2_mavros_imu_data__orientation_z
# uav_2_mavros_local_position_odom__child_frame_id
# uav_2_mavros_local_position_odom__pose_pose_orientation_w
# uav_2_mavros_local_position_odom__pose_pose_orientation_x
# uav_2_mavros_local_position_odom__pose_pose_orientation_y
# uav_2_mavros_local_position_odom__pose_pose_orientation_z
# uav_2_mavros_local_position_odom__pose_pose_position_x
# uav_2_mavros_local_position_odom__pose_pose_position_y
# uav_2_mavros_local_position_odom__pose_pose_position_z
# uav_2_mavros_local_position_odom__twist_twist_angular_x
# uav_2_mavros_local_position_odom__twist_twist_angular_y
# uav_2_mavros_local_position_odom__twist_twist_angular_z
# uav_2_mavros_local_position_odom__twist_twist_linear_x
# uav_2_mavros_local_position_odom__twist_twist_linear_y
# uav_2_mavros_local_position_odom__twist_twist_linear_z
# uav_2_mavros_local_position_pose__pose_orientation_w
# uav_2_mavros_local_position_pose__pose_orientation_x
# uav_2_mavros_local_position_pose__pose_orientation_y
# uav_2_mavros_local_position_pose__pose_orientation_z
# uav_2_mavros_local_position_pose__pose_position_x
# uav_2_mavros_local_position_pose__pose_position_y
# uav_2_mavros_local_position_pose__pose_position_z
# uav_2_mavros_odometry_in__child_frame_id
# uav_2_mavros_odometry_in__pose_pose_orientation_w
# uav_2_mavros_odometry_in__pose_pose_orientation_x
# uav_2_mavros_odometry_in__pose_pose_orientation_y
# uav_2_mavros_odometry_in__pose_pose_orientation_z
# uav_2_mavros_odometry_in__pose_pose_position_x
# uav_2_mavros_odometry_in__pose_pose_position_y
# uav_2_mavros_odometry_in__pose_pose_position_z
# uav_2_mavros_odometry_in__twist_twist_angular_x
# uav_2_mavros_odometry_in__twist_twist_angular_y
# uav_2_mavros_odometry_in__twist_twist_angular_z
# uav_2_mavros_odometry_in__twist_twist_linear_x
# uav_2_mavros_odometry_in__twist_twist_linear_y
# uav_2_mavros_odometry_in__twist_twist_linear_z
# uav_2_mavros_setpoint_raw_target_attitude__body_rate_x
# uav_2_mavros_setpoint_raw_target_attitude__body_rate_y
# uav_2_mavros_setpoint_raw_target_attitude__body_rate_z
# uav_2_mavros_setpoint_raw_target_attitude__orientation_w
# uav_2_mavros_setpoint_raw_target_attitude__orientation_x
# uav_2_mavros_setpoint_raw_target_attitude__orientation_y
# uav_2_mavros_setpoint_raw_target_attitude__orientation_z
# uav_2_mavros_setpoint_raw_target_attitude__thrust
# uav_2_mavros_setpoint_raw_target_attitude__type_mask
# uav_2_mavros_state__armed
# uav_2_mavros_state__connected
# uav_2_mavros_state__guided
# uav_2_mavros_state__mode
# uav_2_mavros_state__system_status
# uav_2_mavros_target_actuator_control__controls0
# uav_2_mavros_target_actuator_control__controls1
# uav_2_mavros_target_actuator_control__controls2
# uav_2_mavros_target_actuator_control__controls3
# uav_2_mavros_target_actuator_control__controls4
# uav_2_mavros_target_actuator_control__controls5
# uav_2_mavros_target_actuator_control__controls6
# uav_2_mavros_target_actuator_control__controls7
# uav_2_mavros_target_actuator_control__group_mix
# uav_3_mavros_extended_state__landed_state
# uav_3_mavros_extended_state__vtol_state
# uav_3_mavros_imu_data__angular_velocity_x
# uav_3_mavros_imu_data__angular_velocity_y
# uav_3_mavros_imu_data__angular_velocity_z
# uav_3_mavros_imu_data__linear_acceleration_x
# uav_3_mavros_imu_data__linear_acceleration_y
# uav_3_mavros_imu_data__linear_acceleration_z
# uav_3_mavros_imu_data__orientation_w
# uav_3_mavros_imu_data__orientation_x
# uav_3_mavros_imu_data__orientation_y
# uav_3_mavros_imu_data__orientation_z
# uav_3_mavros_local_position_odom__child_frame_id
# uav_3_mavros_local_position_odom__pose_pose_orientation_w
# uav_3_mavros_local_position_odom__pose_pose_orientation_x
# uav_3_mavros_local_position_odom__pose_pose_orientation_y
# uav_3_mavros_local_position_odom__pose_pose_orientation_z
# uav_3_mavros_local_position_odom__pose_pose_position_x
# uav_3_mavros_local_position_odom__pose_pose_position_y
# uav_3_mavros_local_position_odom__pose_pose_position_z
# uav_3_mavros_local_position_odom__twist_twist_angular_x
# uav_3_mavros_local_position_odom__twist_twist_angular_y
# uav_3_mavros_local_position_odom__twist_twist_angular_z
# uav_3_mavros_local_position_odom__twist_twist_linear_x
# uav_3_mavros_local_position_odom__twist_twist_linear_y
# uav_3_mavros_local_position_odom__twist_twist_linear_z
# uav_3_mavros_local_position_pose__pose_orientation_w
# uav_3_mavros_local_position_pose__pose_orientation_x
# uav_3_mavros_local_position_pose__pose_orientation_y
# uav_3_mavros_local_position_pose__pose_orientation_z
# uav_3_mavros_local_position_pose__pose_position_x
# uav_3_mavros_local_position_pose__pose_position_y
# uav_3_mavros_local_position_pose__pose_position_z
# uav_3_mavros_odometry_in__child_frame_id
# uav_3_mavros_odometry_in__pose_pose_orientation_w
# uav_3_mavros_odometry_in__pose_pose_orientation_x
# uav_3_mavros_odometry_in__pose_pose_orientation_y
# uav_3_mavros_odometry_in__pose_pose_orientation_z
# uav_3_mavros_odometry_in__pose_pose_position_x
# uav_3_mavros_odometry_in__pose_pose_position_y
# uav_3_mavros_odometry_in__pose_pose_position_z
# uav_3_mavros_odometry_in__twist_twist_angular_x
# uav_3_mavros_odometry_in__twist_twist_angular_y
# uav_3_mavros_odometry_in__twist_twist_angular_z
# uav_3_mavros_odometry_in__twist_twist_linear_x
# uav_3_mavros_odometry_in__twist_twist_linear_y
# uav_3_mavros_odometry_in__twist_twist_linear_z
# uav_3_mavros_setpoint_raw_target_attitude__body_rate_x
# uav_3_mavros_setpoint_raw_target_attitude__body_rate_y
# uav_3_mavros_setpoint_raw_target_attitude__body_rate_z
# uav_3_mavros_setpoint_raw_target_attitude__orientation_w
# uav_3_mavros_setpoint_raw_target_attitude__orientation_x
# uav_3_mavros_setpoint_raw_target_attitude__orientation_y
# uav_3_mavros_setpoint_raw_target_attitude__orientation_z
# uav_3_mavros_setpoint_raw_target_attitude__thrust
# uav_3_mavros_setpoint_raw_target_attitude__type_mask
# uav_3_mavros_state__armed
# uav_3_mavros_state__connected
# uav_3_mavros_state__guided
# uav_3_mavros_state__mode
# uav_3_mavros_state__system_status
# uav_3_mavros_target_actuator_control__controls0
# uav_3_mavros_target_actuator_control__controls1
# uav_3_mavros_target_actuator_control__controls2
# uav_3_mavros_target_actuator_control__controls3
# uav_3_mavros_target_actuator_control__controls4
# uav_3_mavros_target_actuator_control__controls5
# uav_3_mavros_target_actuator_control__controls6
# uav_3_mavros_target_actuator_control__controls7
# uav_3_mavros_target_actuator_control__group_mix

# %% [raw]
# List of columns of recorded topics:
#
# /clock
# /diagnostics
# /*/mavros/odometry/in
# /*/mavros/imu/data
# /*/mavros/state
# /*/mavros/extended_state
# /*/mavros/local_position/odom
# /*/mavros/local_position/pose
# /*/mavros/setpoint_position/local
# /*/mavros/setpoint_raw/attitude
# /*/mavros/setpoint_raw/target_attitude
# /*/mavros/setpoint_raw/target_local
# /*/mavros/target_actuator_control
# /iris_*/force
# /iris_*/odom
# /cable_*/force
# /cable_*/odom
# /load/force
# /load/odom

# %%
def filter_topics(df,topics):
    df_filtered = df[[*topics]]
#     df_filtered = df_filtered.fillna(method='backfill')
#     df_filtered = df_filtered[df_filtered[df_filtered.columns[0]].notnull()]
    return df_filtered

# %%
# Quadrotor - Gazebo

# %%
topics = ['quad_odom__pose_pose_position_x',
          'quad_odom__pose_pose_position_y',
          'quad_odom__pose_pose_position_z']
df_pQ_gazebo = filter_topics(df, topics)

topics = ['quad_odom__twist_twist_linear_x',
          'quad_odom__twist_twist_linear_y',
          'quad_odom__twist_twist_linear_z']
df_vQ_gazebo = filter_topics(df, topics)

topics = ['quad_odom__pose_pose_position_x',
          'quad_odom__pose_pose_position_y',
          'quad_odom__pose_pose_position_z']
df_fQ_gazebo = filter_topics(df, topics)

topics = ['quad_odom__pose_pose_orientation_x',
            'quad_odom__pose_pose_orientation_y',
            'quad_odom__pose_pose_orientation_z',
            'quad_odom__pose_pose_orientation_w']
df_qQ_gazebo = filter_topics(df, topics)

topics = ['quad_odom__twist_twist_angular_x',
            'quad_odom__twist_twist_angular_y',
            'quad_odom__twist_twist_angular_z']
df_oQ_gazebo = filter_topics(df, topics)

topics = ['quad_force__wrench_torque_x',
            'quad_force__wrench_torque_y',
            'quad_force__wrench_torque_z']
df_tauQ_gazebo = filter_topics(df, topics)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-de4e6adbbfec> in <module>
#       2           'quad_odom__pose_pose_position_y',
#       3           'quad_odom__pose_pose_position_z']
# ----> 4 df_pQ_gazebo = filter_topics(df, topics)
#       5
#       6 topics = ['quad_odom__twist_twist_linear_x',
#
# <ipython-input-5-82438e22b0d8> in filter_topics(df, topics)
#       1 def filter_topics(df,topics):
# ----> 2     df_filtered = df[[*topics]]
#       3 #     df_filtered = df_filtered.fillna(method='backfill')
#       4 #     df_filtered = df_filtered[df_filtered[df_filtered.columns[0]].notnull()]
#       5     return df_filtered
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2979             if is_iterator(key):
#    2980                 key = list(key)
# -> 2981             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2982
#    2983         # take() does not accept boolean indexers
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1269                 # When setting, missing keys are not allowed, even with .loc:
#    1270                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1271                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1272         else:
#    1273             try:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1076
#    1077         self._validate_read_indexer(
# -> 1078             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1079         )
#    1080         return keyarr, indexer
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1161                 raise KeyError(
#    1162                     "None of [{key}] are in the [{axis}]".format(
# -> 1163                         key=key, axis=self.obj._get_axis_name(axis)
#    1164                     )
#    1165                 )
#
# KeyError: "None of [Index(['quad_odom__pose_pose_position_x', 'quad_odom__pose_pose_position_y',\n       'quad_odom__pose_pose_position_z'],\n      dtype='object')] are in the [columns]"

# %%
# Load - Gazebo

# %%
topics = ['rb_link_odom__pose_pose_position_x',
          'rb_link_odom__pose_pose_position_y',
          'rb_link_odom__pose_pose_position_z']
df_pL_gazebo = filter_topics(df, topics)

topics = ['rb_link_odom__twist_twist_linear_x',
          'rb_link_odom__twist_twist_linear_y',
          'rb_link_odom__twist_twist_linear_z']
df_vL_gazebo = filter_topics(df, topics)

topics = ['rb_link_force__wrench_force_x',
            'rb_link_force__wrench_force_y',
            'rb_link_force__wrench_force_z']
df_fL_gazebo = filter_topics(df, topics)

topics = ['rb_link_odom__pose_pose_orientation_x',
            'rb_link_odom__pose_pose_orientation_y',
            'rb_link_odom__pose_pose_orientation_z',
            'rb_link_odom__pose_pose_orientation_w']
df_qL_gazebo = filter_topics(df, topics)

topics = ['rb_link_odom__twist_twist_angular_x',
            'rb_link_odom__twist_twist_angular_y',
            'rb_link_odom__twist_twist_angular_z']
df_oL_gazebo = filter_topics(df, topics)

topics = ['rb_link_force__wrench_torque_x',
            'rb_link_force__wrench_torque_y',
            'rb_link_force__wrench_torque_z']
df_tauL_gazebo = filter_topics(df, topics)

# %%
# Quad - ROS Odom

# %%
df_pQ_odom = []
df_vQ_odom = []
df_qQ_odom = []
df_oQ_odom = []
for i in range(number_of_vehicles):
    topics = [ mavros_prefix + str{i} + '_mavros_local_position_odom__pose_pose_position_x',
               mavros_prefix + str{i} + '_mavros_local_position_odom__pose_pose_position_y',
               mavros_prefix + str{i} + '_mavros_local_position_odom__pose_pose_position_z']
    df_pQ_odom.append(filter_topics(df, topics))

    topics = [mavros_prefix + str{i} + '_mavros_local_position_odom__twist_twist_linear_x',
              mavros_prefix + str{i} + '_mavros_local_position_odom__twist_twist_linear_y',
              mavros_prefix + str{i} + '_mavros_local_position_odom__twist_twist_linear_z']
    df_vQ_odom.append(filter_topics(df, topics))

    topics = [mavros_prefix + str{i} + '_mavros_local_position_odom__pose_pose_orientation_x',
                mavros_prefix + str{i} + '_mavros_local_position_odom__pose_pose_orientation_y',
                mavros_prefix + str{i} + '_mavros_local_position_odom__pose_pose_orientation_z',
                mavros_prefix + str{i} + '_mavros_local_position_odom__pose_pose_orientation_w']
    df_qQ_odom.append(filter_topics(df, topics))

    topics = [mavros_prefix + str{i} + '_mavros_local_position_odom__twist_twist_angular_x',
                mavros_prefix + str{i} + '_mavros_local_position_odom__twist_twist_angular_y',
                mavros_prefix + str{i} + '_mavros_local_position_odom__twist_twist_angular_z']
    df_oQ_odom.append(filter_topics(df, topics))

# %%
# Quad - Mavros Pose

# %%
# topics = ['mavros_local_position_pose__pose_pose_position_x',
#           'mavros_local_position_pose__pose_pose_position_y',
#           'mavros_local_position_pose__pose_pose_position_z']
# df_pQ_pose = filter_topics(df, topics)

# topics = ['mavros_local_position_pose__pose_pose_orientation_x',
#             'mavros_local_position_pose__pose_pose_orientation_y',
#             'mavros_local_position_pose__pose_pose_orientation_z',
#             'mavros_local_position_pose__pose_pose_orientation_w']
# df_qQ_pose = filter_topics(df, topics)

# %%
# Quad - Mavros IMU

# %%
topics = ['mavros_imu_data__orientation_x',
            'mavros_imu_data__orientation_y',
            'mavros_imu_data__orientation_z',
            'mavros_imu_data__orientation_w']
df_qQ_imu = filter_topics(df, topics)

topics = ['mavros_imu_data__angular_velocity_x',
            'mavros_imu_data__angular_velocity_y',
            'mavros_imu_data__angular_velocity_z']
df_oQ_imu = filter_topics(df, topics)

# %%
# Quad - Mavros Setpoint Position

# %%
# topics = ['mavros_setpoint_position_local__pose_pose_position_x',
#           'mavros_setpoint_position_local__pose_pose_position_y',
#           'mavros_setpoint_position_local__pose_pose_position_z']
# df_pQ_setpoint = filter_topics(df, topics)

# topics = ['mavros_setpoint_position_local__pose_pose_orientation_x',
#             'mavros_setpoint_position_local__pose_pose_orientation_y',
#             'mavros_setpoint_position_local__pose_pose_orientation_z',
#             'mavros_setpoint_position_local__pose_pose_orientation_w']
# df_qQ_setpoint = filter_topics(df, topics)

# %%
# Quad - Mavros Setpoint Target Position

# %%
# topics = ['mavros_setpoint_raw_target_local__pose_pose_position_x',
#           'mavros_setpoint_raw_target_local__pose_pose_position_y',
#           'mavros_setpoint_raw_target_local__pose_pose_position_z']
# df_pQ_setpoint_target = filter_topics(df, topics)

# topics = ['mavros_setpoint_raw_target_local__pose_pose_orientation_x',
#             'mavros_setpoint_raw_target_local__pose_pose_orientation_y',
#             'mavros_setpoint_raw_target_local__pose_pose_orientation_z',
#             'mavros_setpoint_raw_target_local__pose_pose_orientation_w']
# df_qQ_setpoint_target = filter_topics(df, topics)

# %%
# Quad - Mavros Setpoint Attitude

# %%
topics = ['mavros_setpoint_raw_attitude__body_rate_x',
          'mavros_setpoint_raw_attitude__body_rate_y',
          'mavros_setpoint_raw_attitude__body_rate_z']
df_oQ_setpoint = filter_topics(df, topics)

topics = ['mavros_setpoint_raw_attitude__orientation_x',
            'mavros_setpoint_raw_attitude__orientation_y',
            'mavros_setpoint_raw_attitude__orientation_z',
            'mavros_setpoint_raw_attitude__orientation_w']
df_qQ_setpoint = filter_topics(df, topics)

topics = ['mavros_setpoint_raw_attitude__thrust']
df_TQ_setpoint = filter_topics(df, topics)

# %%
# Quad - Mavros Setpoint Target Attitude

# %%
topics = ['mavros_setpoint_raw_target_attitude__body_rate_x',
          'mavros_setpoint_raw_target_attitude__body_rate_y',
          'mavros_setpoint_raw_target_attitude__body_rate_z']
df_oQ_setpoint_target = filter_topics(df, topics)

topics = ['mavros_setpoint_raw_target_attitude__orientation_x',
            'mavros_setpoint_raw_target_attitude__orientation_y',
            'mavros_setpoint_raw_target_attitude__orientation_z',
            'mavros_setpoint_raw_target_attitude__orientation_w']
df_qQ_setpoint_target = filter_topics(df, topics)

topics = ['mavros_setpoint_raw_target_attitude__thrust']
df_TQ_setpoint_target = filter_topics(df, topics)

# %%
# Quad - Mavros Actuation Target

# %%
topics = ['mavros_target_actuator_control__controls0',
          'mavros_target_actuator_control__controls1',
          'mavros_target_actuator_control__controls2',]
df_tauQ_target = filter_topics(df, topics)

topics = ['mavros_target_actuator_control__controls3',]
df_TQ_target = filter_topics(df, topics)

# %%
# fig, axes = subplots(4, 3, figsize=(20, 15), sharex=True)
fig, axes = subplots(4, 3, figsize=(20, 15))

plot_style = {
#     'marker':'-',
    'markersize':0.2,
    'grid':True,
    'legend':False, 
             }

df_pQ_gazebo.plot(ax=axes[0,0], **plot_style)
df_vQ_gazebo.plot(ax=axes[0,1], **plot_style)
df_fQ_gazebo.plot(ax=axes[0,2], **plot_style)

df_pL_gazebo.plot(ax=axes[1,0], **plot_style)
df_vL_gazebo.plot(ax=axes[1,1], **plot_style)
df_fL_gazebo.plot(ax=axes[1,2], **plot_style)

df_qQ_gazebo.plot(ax=axes[2,0], **plot_style)
df_oQ_gazebo.plot(ax=axes[2,1], **plot_style)
df_tauQ_gazebo.plot(ax=axes[2,2], **plot_style)

df_qL_gazebo.plot(ax=axes[3,0], **plot_style)
df_oL_gazebo.plot(ax=axes[3,1], **plot_style)
df_tauL_gazebo.plot(ax=axes[3,2], **plot_style)

# axes[3,2].set_xlim(pd.Timestamp('1970-01-01 00:00:15'), pd.Timestamp('1970-01-01 00:01:15'));

# %%
topics = ['mavros_setpoint_raw_target_local__position_x',
          'mavros_setpoint_raw_target_local__position_y',
          'mavros_setpoint_raw_target_local__position_z']
mav_target_position = filter_topics(df, topics)

topics = ['mavros_setpoint_raw_target_local__yaw']
mav_target_yaw = filter_topics(df, topics)

topics = ['mavros_setpoint_raw_target_attitude__orientation_x',
          'mavros_setpoint_raw_target_attitude__orientation_y',
          'mavros_setpoint_raw_target_attitude__orientation_z',
          'mavros_setpoint_raw_target_attitude__orientation_w']
mav_target_attitude = filter_topics(df, topics)

topics = ['mavros_target_actuator_control__controls0',
          'mavros_target_actuator_control__controls1',
          'mavros_target_actuator_control__controls2',
          'mavros_target_actuator_control__controls3']
mav_actuators = filter_topics(df, topics)

# %%
fig, axes = subplots(2, 3, figsize=(20, 8))

plot_style = {
    'linestyle':'',
    'marker':'.',
    'markersize':1,
    'grid':True,
    'legend':False, 
             }

df_pQ_gazebo.plot(ax=axes[0,0], **plot_style)
# mav_target_position.plot(ax=axes[0,0], **plot_style)

df_pL_gazebo.plot(ax=axes[0,1], **plot_style)
df_pQ_gazebo.plot(ax=axes[0,1], **plot_style)

(-mav_target_attitude).plot(ax=axes[1,0], **plot_style)
df_qQ_gazebo.plot(ax=axes[1,0], **plot_style)

df_oL_gazebo.plot(ax=axes[0,2], **plot_style)
mav_actuators.iloc[:,0:3].plot(ax=axes[1,1], **plot_style)

df_tauL_gazebo.plot(ax=axes[1,2], **plot_style)
# mav_actuators.plot(ax=axes[1,1], **plot_style)

# %%
fig, axes = subplots(1, 1, figsize=(10, 6))

plot(df_pL_gazebo.index, df_pL_gazebo)
plot(df_pQ_gazebo.index, df_pQ_gazebo)
grid(True)

# %%
fig, axes = subplots(1, 1, figsize=(10, 6))

plot_style = {
    'linestyle':'',
    'marker':'.',
    'markersize':2,
#     'grid':True,
#     'legend':False, 
             }

plot(df_qQ_gazebo.index, df_qQ_gazebo.iloc[:,0:2], **plot_style)
plot(mav_target_attitude.index, mav_target_attitude.iloc[:,0:2], **plot_style)
grid(True)

# %%
fig, axes = subplots(1, 1, figsize=(10,6))

plot(df_qQ_gazebo.index, df_qQ_gazebo.iloc[:,0:2])
plot(mav_target_attitude.index, -mav_target_attitude.iloc[:,0:2])
grid(True)

# %%
fig, axes = subplots(1, 1, figsize=(10,6))

plot(df_qQ_gazebo.index, df_qQ_gazebo.iloc[:,0:2])
plot(mav_target_attitude.index, -mav_target_attitude.iloc[:,0:2])
# plot(df_oL_gazebo.index, df_oL_gazebo)
grid(True)

# %%
fig, axes = subplots(1, 1, figsize=(10,6))

# plot(df_qL_gazebo.index, df_qL_gazebo.iloc[:,0:2])
# plot(mav_target_attitude.index, -mav_target_attitude.iloc[:,0:2])
plot(df_oL_gazebo.index, df_oL_gazebo, linestyle="", marker='.', markersize=1)
grid(True)

# %%
fig, axes = subplots(1, 1, figsize=(10,6))

# plot(df_qL_gazebo.index, df_qL_gazebo.iloc[:,0:2])
# plot(mav_target_attitude.index, -mav_target_attitude.iloc[:,0:2])
plot(df_tauL_gazebo.index, df_tauL_gazebo, linestyle="", marker='.', markersize=1)
grid(True)

# %%
t = pd.to_timedelta(df_pQ_gazebo.index - df_pQ_gazebo.index[0] ).total_seconds().to_numpy()

pQ = transform_position_I(df_pQ_gazebo.values.reshape(-1,1,3,1))
pL = transform_position_I(df_pL_gazebo.values.reshape(-1,1,3,1))
vQ = transform_position_I(df_vQ_gazebo.values.reshape(-1,1,3,1))
vL = transform_position_I(df_vL_gazebo.values.reshape(-1,1,3,1))
aQ = transform_position_I(df_fQ_gazebo.values.reshape(-1,1,3,1))
aL = transform_position_I(df_fL_gazebo.values.reshape(-1,1,3,1))

pQ = np.nan_to_num(pQ)
pL = np.nan_to_num(pL)
vQ = np.nan_to_num(vQ)
vL = np.nan_to_num(vL)
aQ = np.nan_to_num(aQ)
aQ = np.nan_to_num(aL)

actuation = mav_actuators.values.reshape(-1,1,4,1)
target_attitude = mav_target_attitude.values.reshape(-1,1,4,1)

# %%
def skew(v):
    # New shape is v shape with last dimension 3 instead of 1 (3x1 vector --> 3x3 matrix)
    s = np.asarray(v.shape)
    s[-1] = 3
    
    # Vectorize
    # Maintains the shape of v for vi
    v0 = v[...,0,0,np.newaxis,np.newaxis]
    v1 = v[...,1,0,np.newaxis,np.newaxis]
    v2 = v[...,2,0,np.newaxis,np.newaxis]

    z = np.zeros_like(v0)
    
    # TODO: Check that dim(v) = 3
    res = np.concatenate([z, -v2, v1,
                    v2, z, -v0,
                    -v1, v0, z],axis=-2)
    
    return res.reshape(s)

def unskew(M):
    # New shape is M shape with last dimension 1 instead of 3 (3x3 matrix --> 3x1 vector)
    s = np.asarray(M.shape)
    s[-1] = 1

    # TODO: Check if M is anti-symmetric
#     TODO: stack along axis=-1 instead of using reshape()
    
    res = np.stack([-M[...,1,2].reshape(-1,1),
                  M[...,0,2].reshape(-1,1),
                  -M[...,0,1].reshape(-1,1)],axis=1).reshape(s)
    
    return res

# TODO: Check that unskew(skew(v)) == v
# TODO: Do not make assumptions on shape of input

# %%
def mt(M):
# Matrix transpose no matter what is M shape.  M = (...) x n x m or M = (...) x m x n
    
    return np.swapaxes(M,-1,-2)

# %%
l = norm(pL - pQ, axis=-2, keepdims=True)

q = (pL - pQ) / norm(pL - pQ, axis=-2, keepdims=True)
q = np.nan_to_num(q)

dq = (np.eye(3) - q @ mt(q)) @ (vL - vQ) / norm(pL - pQ, axis=-2, keepdims=True)
dq = np.nan_to_num(dq)

o = - skew(q) @ dq

n = len(pQ)

# %%
plot(np.squeeze(l[:-1]))

# %%
RL = np.repeat(np.eye(3).reshape(-1,1,3,3),n,axis=0)
oL = np.zeros([n,1,3,1])
RQ = np.repeat(np.eye(3).reshape(-1,1,3,3),n,axis=0)
oQ = np.zeros([n,1,3,1])
delta_TLd = np.zeros([n,1,3,1])
V = np.zeros([n,1,1,1])

# print("===================================")

y = pack_solution(pL,
            vL,
            RL,
            oL,
            delta_TLd,
            q,
            o,
            RQ,
            oQ,
            V)

t = pd.to_timedelta(df_pQ_gazebo.index - df_pQ_gazebo.index[0] ).total_seconds().to_numpy()

dy, state = process_state(t,mt(y))

# %%
fig, axes = subplots(5, 3, figsize=(20, 16))

all_axes = [ax.grid() for sublist in axes for ax in sublist]

axes[0,0].plot(t,squeeze(pL))
axes[0,1].plot(t,squeeze(vL))
axes[0,2].plot(t,squeeze(aL))

axes[1,0].plot(t,squeeze(pQ))
axes[1,1].plot(t,squeeze(vQ))
axes[1,2].plot(t,squeeze(aQ))

axes[2,0].plot(t,squeeze(q))
axes[2,1].plot(t[:-1],squeeze(o[:-1,...]))
# axes[2,1].set_ylim([-0.01,0.01])
axes[2,2].plot(t,squeeze(state.u_perp))

axes[3,0].plot(t,squeeze(state.q-state.qd))
axes[3,1].plot(t,squeeze(state.F-state.Fd))
# axes[3,2].plot(t,squeeze(state.F))
axes[3,2].plot(t,squeeze(state.qF))

axes[4,0].plot(t,squeeze(mav_target_attitude))
axes[4,1].plot(t,squeeze(mav_actuators))
# axes[3,2].plot(t,squeeze(state.F))
# axes[4,2].plot(t,squeeze(state.qF))

# target_attitude

# %% [markdown]
# # Comparisons

# %% [markdown]
# ## Position

# %%
fig, axes = subplots(1, 3, figsize=(15, 4))

all_axes = [ax.grid() for ax in axes]

axes[0].plot(t,squeeze(df_pQ_gazebo.values))
axes[1].plot(t,squeeze(df_pQ_odom))
axes[2].plot(t,squeeze(df_pQ_gazebo.values - df_pQ_odom))

# %%
fig, axes = subplots(2, 3, figsize=(15, 4))

all_axes = [ax.grid() for sublist in axes for ax in sublist]

axes[0,0].plot(t,squeeze(df_pQ_gazebo.values))
axes[0,1].plot(t,squeeze(df_vQ_gazebo.values))
# axes[2].plot(t,squeeze(cumtrapz(df_vQ_gazebo.values,t,axis=0,initial=0)))
axes[0,2].plot(t,squeeze(df_pQ_gazebo.values-cumtrapz(df_vQ_gazebo.values,t,axis=0,initial=0)-df_pQ_gazebo.values[0,:]))
axes[1,0].plot(t,squeeze(df_pL_gazebo.values))
axes[1,1].plot(t,squeeze(df_vL_gazebo.values))
# axes[2].plot(t,squeeze(cumtrapz(df_vQ_gazebo.values,t,axis=0,initial=0)))
axes[1,2].plot(t,squeeze(df_pL_gazebo.values-cumtrapz(df_vL_gazebo.values,t,axis=0,initial=0)-df_pL_gazebo.values[0,:]))

# %% [markdown]
# ## Attitude

# %%
df_qQ_gazebo.values[:,0] = -df_qQ_gazebo.values[:,0] * np.sign(df_qQ_gazebo.values[:,3])
df_qQ_gazebo.values[:,1] = -df_qQ_gazebo.values[:,1] * np.sign(df_qQ_gazebo.values[:,3])
df_qQ_gazebo.values[:,2] = -df_qQ_gazebo.values[:,2] * np.sign(df_qQ_gazebo.values[:,3])
df_qQ_gazebo.values[:,3] = -df_qQ_gazebo.values[:,3] * np.sign(df_qQ_gazebo.values[:,3])

# %%
fig, axes = subplots(3, 3, figsize=(20, 15))

all_axes = [ax.grid() for sublist in axes for ax in sublist]

plot_options = {'linestyle':"", 'marker':'.', 'markersize':1}

axes[0,0].plot(t,squeeze(df_qQ_gazebo.values), **plot_options)
axes[0,1].plot(t,squeeze(df_qQ_imu.values), **plot_options)
axes[0,2].plot(t,squeeze(df_qQ_odom.values), **plot_options)
axes[1,0].plot(t,squeeze(df_qQ_setpoint.values), **plot_options)
axes[1,1].plot(t,squeeze(df_qQ_setpoint_target.values), **plot_options)
axes[1,2].plot(t,squeeze(df_qQ_imu.values - df_qQ_odom.values), **plot_options)
axes[2,0].plot(t,squeeze(df_qQ_gazebo.values - df_qQ_imu.values), **plot_options)
axes[2,1].plot(t,squeeze(df_qQ_gazebo.values - df_qQ_odom.values), **plot_options)
axes[2,2].plot(t,squeeze(df_qQ_gazebo.values - df_qQ_setpoint.values), **plot_options)

# %% [markdown]
# ## Load angle

# %%
fig, axes = subplots(3, 3, figsize=(20, 15))

all_axes = [ax.grid() for sublist in axes for ax in sublist]

plot_options = {'linestyle':"", 'marker':'.', 'markersize':1}

axes[0,0].plot(t,squeeze(state.q), **plot_options)
axes[0,1].plot(t,squeeze(state.qd), **plot_options)
axes[0,2].plot(t,squeeze(state.q - state.qd), **plot_options)
axes[1,0].plot(t,squeeze(state.q_actuation), **plot_options)
axes[1,1].plot(t,squeeze(state.e_q), **plot_options)
axes[1,2].plot(t,squeeze(state.e_oq), **plot_options)

# %% [markdown]
# ## State vars

# %%
fig, axes = subplots(3, 3, figsize=(20, 15))

all_axes = [ax.grid() for sublist in axes for ax in sublist]

plot_options = {'linestyle':"", 'marker':'.', 'markersize':1}

axes[0,0].plot(t,squeeze(state.mud), **plot_options)
axes[0,1].plot(t,squeeze(state.mu), **plot_options)
axes[0,2].plot(t,squeeze(state.mu - state.mud), **plot_options)

axes[1,0].plot(t,squeeze(state.Fd), **plot_options)
axes[1,1].plot(t,squeeze(state.TLd), **plot_options)

axes[2,0].plot(t,squeeze(state.u), **plot_options)
axes[2,1].plot(t,squeeze(state.u_parallel), t,squeeze(state.mu), **plot_options)
axes[2,2].plot(t,squeeze(state.u_perp), **plot_options)

# %%
# u_parallel = mu + mQ * lq * norm(oq, axis=-2, keepdims=True)**2 * q + mQ * q @ mt(q) @ a
fig, axes = subplots(3, 3, figsize=(20, 15))

all_axes = [ax.grid() for sublist in axes for ax in sublist]

plot_options = {'linestyle':"", 'marker':'.', 'markersize':1}

axes[0,0].plot(t,squeeze(state.mu), **plot_options)
axes[0,1].plot(t,squeeze(mQ * lq * norm(state.oq, axis=-2, keepdims=True)**2 * state.q), **plot_options)
axes[0,2].plot(t,squeeze(mQ * state.q @ mt(state.q) @ state.a), **plot_options)
axes[1,0].plot(t,squeeze(state.q))
axes[1,1].plot(t,squeeze(state.dq))
axes[1,2].plot(t,squeeze(state.oq))
axes[2,0].plot(t,squeeze(q))
axes[2,1].plot(t,squeeze((np.eye(3) - q @ mt(q)) @ (vL - vQ) / norm(pL - pQ, axis=-2, keepdims=True)))
axes[2,2].plot(t,squeeze(q),t,squeeze((vL - vQ) / norm(pL - pQ, axis=-2, keepdims=True)))

# %%
fig, axes = subplots(5, 3, figsize=(20, 15))

all_axes = [ax.grid() for sublist in axes for ax in sublist]
# all_axes = [ax.set_xlim([20,30]) for sublist in axes for ax in sublist]
plot_options = {'linestyle':"", 'marker':'.', 'markersize':1}

axes[0,0].plot(t,squeeze(state.q), **plot_options)
axes[0,1].plot(t,squeeze(state.oq), **plot_options)
axes[0,1].set_ylim([-1,1])
axes[0,2].plot(t,squeeze(state.doq), **plot_options)

axes[1,0].plot(t,squeeze(state.qd),t,squeeze(state.qd), **plot_options)
axes[1,1].plot(t,squeeze(state.oqd), **plot_options)
axes[1,1].set_ylim([-1,1])
axes[1,2].plot(t,squeeze(state.doqd), **plot_options)

axes[2,0].plot(t,squeeze(state.q),t,squeeze(state.qd), **plot_options)
axes[2,1].plot(t,squeeze(state.oq),t,squeeze(state.oqd), **plot_options)
axes[2,1].set_ylim([-1,1])
axes[2,2].plot(t,squeeze(state.zoq), **plot_options)

axes[3,0].plot(t,squeeze(state.oq), **plot_options)
axes[3,1].plot(t[:-1],50*diff(squeeze(state.oq),axis=0), **plot_options)
axes[3,1].set_ylim([-2,2])
axes[3,2].plot(t,squeeze(state.doq), **plot_options)

# %%
# u_perp_d =  (mQ * lq) * skew(q) @ (
#         - 1 / lq * skew(q) @ a 
#         - skew(dq) @ skew(q) @ oqd
#         - skew(q) @ skew(dq) @ oqd
#         - skew(q) @ skew(q) @ doqd
#         - 1 / L_q * (
#                 + (mt(dqd) @ TLd) * skew(q)
#                 + (mt(qd) @ dTLd) * skew(q)
#                 + (mt(qd) @ TLd) * skew(dq)
#             ) @ (
#                     1/mL * (x_pv * pe + ve)
#                 )
#         - 1 / L_q * (mt(qd) @ TLd) * skew(q) @ (
#             1/mL * (x_pv * ve + ae)
#         ) 
#         + koq / L_oq * zoq
#         + L_q / L_oq * skew(q) @ qd
#     )

# %%
fig, axes = subplots(2, 2, figsize=(20, 15))

all_axes = [ax.set_xlim([10,20]) for sublist in axes for ax in sublist]
all_axes = [ax.grid() for sublist in axes for ax in sublist]

axes[0,0].plot(t[:-1],50*diff(squeeze(state.oq),axis=0)[:,0], **plot_options)
axes[0,0].set_ylim([-2,2])
axes[0,0].plot(t,squeeze(state.doq)[:,0], **plot_options)

axes[0,1].plot(t[:-1],50*diff(squeeze(state.oq),axis=0)[:,1], **plot_options)
axes[0,1].set_ylim([-2,2])
axes[0,1].plot(t,squeeze(state.doq)[:,1], **plot_options)

axes[1,0].plot(t[:-1],50*diff(squeeze(state.oq),axis=0)[:,2], **plot_options)
axes[1,0].set_ylim([-2,2])
axes[1,0].plot(t,squeeze(state.doq)[:,2], **plot_options)

axes[1,1].plot(t[:-1],50*diff(squeeze(state.oq),axis=0), **plot_options)
axes[1,1].set_ylim([-2,2])
axes[1,1].plot(t,squeeze(state.doq), **plot_options)

# %%
fig, axes = subplots(2, 2, figsize=(20, 15))

all_axes = [ax.set_xlim([10,20]) for sublist in axes for ax in sublist]
all_axes = [ax.grid() for sublist in axes for ax in sublist]

axes[0,0].plot(t[:-1],50*diff(squeeze(state.oq),axis=0)[:,0], **plot_options)
axes[0,0].set_ylim([-2,2])
axes[0,0].plot(t,squeeze(- 1 / (mQ * lq) * skew(state.q) @ state.u_perp)[:,0], **plot_options)

axes[0,1].plot(t[:-1],50*diff(squeeze(state.oq),axis=0)[:,1], **plot_options)
axes[0,1].set_ylim([-2,2])
axes[0,1].plot(t,squeeze(- 1 / (mQ * lq) * skew(state.q) @ state.u_perp)[:,1], **plot_options)

axes[1,0].plot(t[:-1],50*diff(squeeze(state.oq),axis=0)[:,2], **plot_options)
axes[1,0].set_ylim([-2,2])
axes[1,0].plot(t,squeeze(- 1 / (mQ * lq) * skew(state.q) @ state.u_perp)[:,2], **plot_options)

axes[1,1].plot(t[:-1],50*diff(squeeze(state.oq),axis=0), **plot_options)
axes[1,1].set_ylim([-2,2])
axes[1,1].plot(t,squeeze(- 1 / (mQ * lq) * skew(state.q) @ state.u_perp), **plot_options)

# %%
fig, axes = subplots(4, 3, figsize=(20, 15))

all_axes = [ax.grid() for sublist in axes for ax in sublist]
all_axes = [ax.set_xlim([10,20]) for sublist in axes for ax in sublist]
plot_options = {'linestyle':"", 'marker':'.', 'markersize':1}

axes[0,0].plot(t,squeeze(state.p), **plot_options)
axes[0,1].plot(t,squeeze(state.v), **plot_options)
axes[0,2].plot(t,squeeze(state.dv), **plot_options)
# axes[0,2].plot(t,squeeze(state.doq), **plot_options)

axes[1,0].plot(t,squeeze(df_pL_gazebo.values))
axes[1,1].plot(t,squeeze(df_vL_gazebo.values))
axes[1,2].plot(t[:-1],50*diff(squeeze(df_vL_gazebo.values),axis=0))

axes[2,0].plot(t,squeeze(state.p), t,squeeze(df_pL_gazebo.values))
axes[2,1].plot(t,squeeze(state.v), t,squeeze(df_vL_gazebo.values))
axes[2,2].plot(t,squeeze(state.dv), t[:-1],50*diff(squeeze(df_vL_gazebo.values),axis=0))

axes[3,0].plot(t,squeeze(state.dv), **plot_options)
axes[3,1].plot(t,squeeze(state.Fd), **plot_options)
axes[3,2].plot(t,squeeze(state.F), **plot_options)
# axes[0,2].plot(t,squeeze(state.doq), **plot_options)

# %%
fig, axes = subplots(3, 3, figsize=(20, 15))

all_axes = [ax.grid() for sublist in axes for ax in sublist]
all_axes = [ax.set_xlim([10,20]) for sublist in axes for ax in sublist]
plot_options = {'linestyle':"", 'marker':'.', 'markersize':1}

axes[0,0].plot(t,squeeze(df_qQ_gazebo.values), **plot_options)
axes[0,1].plot(t,squeeze(df_qQ_setpoint_target.values), **plot_options)
axes[0,2].plot(t,squeeze(df_qQ_gazebo.values), t,squeeze(df_qQ_setpoint_target.values), **plot_options)


axes[1,0].plot(t,squeeze(df_TQ_target), **plot_options)
axes[1,1].plot(t,squeeze(df_TQ_setpoint), **plot_options)
axes[1,2].plot(t,squeeze(df_TQ_target),t,squeeze(df_TQ_setpoint), **plot_options)

# %%
fig, axes = subplots(2, 2, figsize=(20, 15))

all_axes = [ax.set_xlim([10,20]) for sublist in axes for ax in sublist]
all_axes = [ax.grid() for sublist in axes for ax in sublist]

axes[0,0].plot(t[:-1],50*diff(squeeze(state.oq),axis=0)[:,0], **plot_options)
axes[0,0].set_ylim([-2,2])
axes[0,0].plot(t,squeeze( 1 / (mQ * lq) * skew(state.q) @ state.u_perp)[:,0], **plot_options)

axes[0,1].plot(t[:-1],50*diff(squeeze(state.oq),axis=0)[:,1], **plot_options)
axes[0,1].set_ylim([-2,2])
axes[0,1].plot(t,squeeze( 1 / (mQ * lq) * skew(state.q) @ state.u_perp)[:,1], **plot_options)

axes[1,0].plot(t[:-1],50*diff(squeeze(state.oq),axis=0)[:,2], **plot_options)
axes[1,0].set_ylim([-2,2])
axes[1,0].plot(t,squeeze( 1 / (mQ * lq) * skew(state.q) @ state.u_perp)[:,2], **plot_options)

axes[1,1].plot(t[:-1],50*diff(squeeze(state.oq),axis=0), **plot_options)
axes[1,1].set_ylim([-2,2])
axes[1,1].plot(t,squeeze( 1 / (mQ * lq) * skew(state.q) @ state.u_perp), **plot_options)
